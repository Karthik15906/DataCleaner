# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from DataCleaner import DataCleaner

# %%
cleaner = DataCleaner('students.csv',missing='drop',duplicates=True,show_log=True,show_corr=True)
df = cleaner.clean()
print(df.head())
# Out:
# [DataCleaner INFO]: Loading Data from students.csv
# [DataCleaner INFO]: Data loaded sucessfully with shape (5001, 19)
# [DataCleaner INFO]: Removed 0 duplicate rows
# [DataCleaner INFO]: Current data shape: (5001, 19)
# [DataCleaner INFO]: Handling missing values using: drop
#
# Correlation Matrix
#
#                         Student ID  Admission Year  Graduate Year  \
# Student ID                    1.00            0.01           0.01
# Admission Year                0.01            1.00           0.90
# Graduate Year                 0.01            0.90           1.00
# Expected Graduate Year        0.00            0.90           0.81
# Secondary School GPA         -0.01            0.01           0.01
# GAT Scores                    0.03            0.01           0.02
# AAT Score                     0.00            0.01           0.00
# Student GPA                   0.00            0.01           0.00
# Last Semester GPA             0.00           -0.00          -0.00
# Math Score                   -0.01           -0.01          -0.02
# CS Score                     -0.02           -0.01          -0.01
# English Score                -0.01           -0.01          -0.02
# Admission Score              -0.01            0.00          -0.00
#
#                         Expected Graduate Year  Secondary School GPA  \
# Student ID                                0.00                 -0.01
# Admission Year                            0.90                  0.01
# Graduate Year                             0.81                  0.01
# Expected Graduate Year                    1.00                  0.00
# Secondary School GPA                      0.00                  1.00
# GAT Scores                                0.01                 -0.01
# AAT Score                                 0.01                 -0.02
# Student GPA                               0.01                 -0.02
# Last Semester GPA                         0.00                 -0.01
# Math Score                               -0.00                 -0.03
# CS Score                                  0.01                 -0.02
# English Score                            -0.00                 -0.03
# Admission Score                           0.00                 -0.03
#
#                         GAT Scores  AAT Score  Student GPA  Last Semester GPA  \
# Student ID                    0.03       0.00         0.00               0.00
# Admission Year                0.01       0.01         0.01              -0.00
# Graduate Year                 0.02       0.00         0.00              -0.00
# Expected Graduate Year        0.01       0.01         0.01               0.00
# Secondary School GPA         -0.01      -0.02        -0.02              -0.01
# GAT Scores                    1.00       0.00        -0.00               0.01
# AAT Score                     0.00       1.00        -0.02              -0.01
# Student GPA                  -0.00      -0.02         1.00               0.95
# Last Semester GPA             0.01      -0.01         0.95               1.00
# Math Score                   -0.00      -0.02         0.67               0.62
# CS Score                      0.01      -0.02         0.66               0.62
# English Score                -0.00      -0.02         0.67               0.62
# Admission Score              -0.00      -0.02         0.90               0.85
#
#                         Math Score  CS Score  English Score  Admission Score
# Student ID                   -0.01     -0.02          -0.01            -0.01
# Admission Year               -0.01     -0.01          -0.01             0.00
# Graduate Year                -0.02     -0.01          -0.02            -0.00
# Expected Graduate Year       -0.00      0.01          -0.00             0.00
# Secondary School GPA         -0.03     -0.02          -0.03            -0.03
# GAT Scores                   -0.00      0.01          -0.00            -0.00
# AAT Score                    -0.02     -0.02          -0.02            -0.02
# Student GPA                   0.67      0.66           0.67             0.90
# Last Semester GPA             0.62      0.62           0.62             0.85
# Math Score                    1.00      0.53           1.00             0.73
# CS Score                      0.53      1.00           0.53             0.73
# English Score                 1.00      0.53           1.00             0.73
# Admission Score               0.73      0.73           0.73             1.00
# [DataCleaner INFO]: Cleaning complete
#    Student ID     Sex   Campus Name Major Student Status  Admission Year  \
# 0    100000.0    Male  North Campus  CNET        regular          2019.0
# 2    100002.0    Male   West Campus    IT        regular          2018.0
# 3    100003.0    Male   Main Campus    CS  discontinuous          2019.0
# 4    100004.0    Male  North Campus  CNET       graduate          2016.0
# 5    100005.0  Female   Main Campus  CNET  discontinuous          2018.0
#
#    Graduate Year  Expected Graduate Year  Secondary School GPA  GAT Scores  \
# 0         2024.0                  2022.0                 62.52        66.0
# 2         2022.0                  2023.0                 80.65        90.0
# 3         2022.0                  2024.0                 99.12        51.0
# 4         2022.0                  2022.0                 83.79        61.0
# 5         2024.0                  2021.0                 97.96        91.0
#
#    AAT Score School Name  Student GPA  Last Semester GPA  Math Score  \
# 0       59.0    School B         3.85               3.72        93.0
# 2       61.0    School C         1.55               1.78        36.0
# 3       65.0    School C         1.36               1.46        35.0
# 4       60.0    School A         3.58               3.24        81.0
# 5       66.0    School B         4.18               3.84        59.0
#
#    CS Score  English Score  Admission Score Grade
# 0      75.0           93.0             85.0     B
# 2      47.0           36.0             38.0     D
# 3      64.0           35.0             41.0     D
# 4      92.0           81.0             69.0     B
# 5      52.0           59.0             82.0     A

# %%
cleaner = DataCleaner('students.csv',missing='median',duplicates=False,show_log=True)
df = cleaner.clean()
print(df.head())
# Out:
# [DataCleaner INFO]: Loading Data from students.csv
# [DataCleaner INFO]: Data loaded sucessfully with shape (5001, 19)
# [DataCleaner INFO]: Duplicates removal skipped
# [DataCleaner INFO]: Handling missing values using: median
#
# Correlation Matrix
#
#                         Student ID  Admission Year  Graduate Year  \
# Student ID                    1.00            0.01           0.01
# Admission Year                0.01            1.00           0.89
# Graduate Year                 0.01            0.89           1.00
# Expected Graduate Year        0.01            0.89           0.80
# Secondary School GPA         -0.00            0.01           0.02
# GAT Scores                    0.03            0.01           0.01
# AAT Score                     0.01            0.01           0.01
# Student GPA                  -0.01            0.01           0.01
# Last Semester GPA            -0.01            0.00          -0.00
# Math Score                   -0.02           -0.00          -0.01
# CS Score                     -0.02           -0.00          -0.01
# English Score                -0.01           -0.00          -0.01
# Admission Score              -0.01            0.01          -0.00
#
#                         Expected Graduate Year  Secondary School GPA  \
# Student ID                                0.01                 -0.00
# Admission Year                            0.89                  0.01
# Graduate Year                             0.80                  0.02
# Expected Graduate Year                    1.00                  0.01
# Secondary School GPA                      0.01                  1.00
# GAT Scores                                0.01                  0.00
# AAT Score                                 0.01                 -0.02
# Student GPA                               0.01                 -0.03
# Last Semester GPA                         0.00                 -0.02
# Math Score                               -0.00                 -0.02
# CS Score                                  0.01                 -0.02
# English Score                             0.00                 -0.02
# Admission Score                           0.01                 -0.03
#
#                         GAT Scores  AAT Score  Student GPA  Last Semester GPA  \
# Student ID                    0.03       0.01        -0.01              -0.01
# Admission Year                0.01       0.01         0.01               0.00
# Graduate Year                 0.01       0.01         0.01              -0.00
# Expected Graduate Year        0.01       0.01         0.01               0.00
# Secondary School GPA          0.00      -0.02        -0.03              -0.02
# GAT Scores                    1.00       0.00        -0.01               0.00
# AAT Score                     0.00       1.00        -0.02              -0.01
# Student GPA                  -0.01      -0.02         1.00               0.95
# Last Semester GPA             0.00      -0.01         0.95               1.00
# Math Score                   -0.00      -0.02         0.66               0.61
# CS Score                      0.00      -0.01         0.66               0.62
# English Score                -0.01      -0.02         0.66               0.61
# Admission Score              -0.01      -0.01         0.90               0.84
#
#                         Math Score  CS Score  English Score  Admission Score
# Student ID                   -0.02     -0.02          -0.01            -0.01
# Admission Year               -0.00     -0.00          -0.00             0.01
# Graduate Year                -0.01     -0.01          -0.01            -0.00
# Expected Graduate Year       -0.00      0.01           0.00             0.01
# Secondary School GPA         -0.02     -0.02          -0.02            -0.03
# GAT Scores                   -0.00      0.00          -0.01            -0.01
# AAT Score                    -0.02     -0.01          -0.02            -0.01
# Student GPA                   0.66      0.66           0.66             0.90
# Last Semester GPA             0.61      0.62           0.61             0.84
# Math Score                    1.00      0.52           0.99             0.73
# CS Score                      0.52      1.00           0.52             0.72
# English Score                 0.99      0.52           1.00             0.73
# Admission Score               0.73      0.72           0.73             1.00
# [DataCleaner INFO]: Cleaning complete
#    Student ID     Sex   Campus Name Major Student Status  Admission Year  \
# 0    100000.0    Male  North Campus  CNET        regular          2019.0
# 1    100001.0  Female  North Campus  CNET  discontinuous          2019.0
# 2    100002.0    Male   West Campus    IT        regular          2018.0
# 3    100003.0    Male   Main Campus    CS  discontinuous          2019.0
# 4    100004.0    Male  North Campus  CNET       graduate          2016.0
#
#    Graduate Year  Expected Graduate Year  Secondary School GPA  GAT Scores  \
# 0         2024.0                  2022.0                 62.52        66.0
# 1         2028.0                  2026.0                 92.41        76.0
# 2         2022.0                  2023.0                 80.65        90.0
# 3         2022.0                  2024.0                 99.12        51.0
# 4         2022.0                  2022.0                 83.79        61.0
#
#    AAT Score School Name  Student GPA  Last Semester GPA  Math Score  \
# 0       59.0    School B         3.85               3.72        93.0
# 1       75.0    School B         3.81               4.00        98.0
# 2       61.0    School C         1.55               1.78        36.0
# 3       65.0    School C         1.36               1.46        35.0
# 4       60.0    School A         3.58               3.24        81.0
#
#    CS Score  English Score  Admission Score Grade
# 0      75.0           93.0             85.0     B
# 1      78.0           99.0             81.0     B
# 2      47.0           36.0             38.0     D
# 3      64.0           35.0             41.0     D
# 4      92.0           81.0             69.0     B

# %%
cleaner = DataCleaner('students.csv',missing='mean',duplicates=False,show_log=True)
df = cleaner.clean()
print(df.head())
# Out:
# [DataCleaner INFO]: Loading Data from students.csv
# [DataCleaner INFO]: Data loaded sucessfully with shape (5001, 19)
# [DataCleaner INFO]: Duplicates removal skipped
# [DataCleaner INFO]: Handling missing values using: mean
#
# Correlation Matrix
#
#                         Student ID  Admission Year  Graduate Year  \
# Student ID                    1.00            0.01           0.01
# Admission Year                0.01            1.00           0.89
# Graduate Year                 0.01            0.89           1.00
# Expected Graduate Year        0.01            0.89           0.80
# Secondary School GPA         -0.00            0.01           0.02
# GAT Scores                    0.03            0.01           0.01
# AAT Score                     0.01            0.01           0.01
# Student GPA                  -0.01            0.01           0.01
# Last Semester GPA            -0.01            0.00          -0.00
# Math Score                   -0.02           -0.00          -0.01
# CS Score                     -0.02           -0.00          -0.01
# English Score                -0.01           -0.00          -0.01
# Admission Score              -0.01            0.01          -0.00
#
#                         Expected Graduate Year  Secondary School GPA  \
# Student ID                                0.01                 -0.00
# Admission Year                            0.89                  0.01
# Graduate Year                             0.80                  0.02
# Expected Graduate Year                    1.00                  0.01
# Secondary School GPA                      0.01                  1.00
# GAT Scores                                0.01                  0.00
# AAT Score                                 0.01                 -0.02
# Student GPA                               0.01                 -0.03
# Last Semester GPA                         0.00                 -0.02
# Math Score                               -0.00                 -0.02
# CS Score                                  0.01                 -0.02
# English Score                             0.00                 -0.02
# Admission Score                           0.01                 -0.03
#
#                         GAT Scores  AAT Score  Student GPA  Last Semester GPA  \
# Student ID                    0.03       0.01        -0.01              -0.01
# Admission Year                0.01       0.01         0.01               0.00
# Graduate Year                 0.01       0.01         0.01              -0.00
# Expected Graduate Year        0.01       0.01         0.01               0.00
# Secondary School GPA          0.00      -0.02        -0.03              -0.02
# GAT Scores                    1.00       0.00        -0.01               0.00
# AAT Score                     0.00       1.00        -0.02              -0.01
# Student GPA                  -0.01      -0.02         1.00               0.95
# Last Semester GPA             0.00      -0.01         0.95               1.00
# Math Score                   -0.00      -0.02         0.66               0.61
# CS Score                      0.00      -0.01         0.66               0.62
# English Score                -0.01      -0.02         0.66               0.61
# Admission Score              -0.01      -0.01         0.90               0.84
#
#                         Math Score  CS Score  English Score  Admission Score
# Student ID                   -0.02     -0.02          -0.01            -0.01
# Admission Year               -0.00     -0.00          -0.00             0.01
# Graduate Year                -0.01     -0.01          -0.01            -0.00
# Expected Graduate Year       -0.00      0.01           0.00             0.01
# Secondary School GPA         -0.02     -0.02          -0.02            -0.03
# GAT Scores                   -0.00      0.00          -0.01            -0.01
# AAT Score                    -0.02     -0.01          -0.02            -0.01
# Student GPA                   0.66      0.66           0.66             0.90
# Last Semester GPA             0.61      0.62           0.61             0.84
# Math Score                    1.00      0.52           0.99             0.73
# CS Score                      0.52      1.00           0.52             0.72
# English Score                 0.99      0.52           1.00             0.73
# Admission Score               0.73      0.72           0.73             1.00
# [DataCleaner INFO]: Cleaning complete
#    Student ID     Sex   Campus Name Major Student Status  Admission Year  \
# 0    100000.0    Male  North Campus  CNET        regular     2019.000000
# 1    100001.0  Female  North Campus  CNET  discontinuous     2018.507866
# 2    100002.0    Male   West Campus    IT        regular     2018.000000
# 3    100003.0    Male   Main Campus    CS  discontinuous     2019.000000
# 4    100004.0    Male  North Campus  CNET       graduate     2016.000000
#
#    Graduate Year  Expected Graduate Year  Secondary School GPA  GAT Scores  \
# 0         2024.0                  2022.0                 62.52        66.0
# 1         2028.0                  2026.0                 92.41        76.0
# 2         2022.0                  2023.0                 80.65        90.0
# 3         2022.0                  2024.0                 99.12        51.0
# 4         2022.0                  2022.0                 83.79        61.0
#
#    AAT Score School Name  Student GPA  Last Semester GPA  Math Score  \
# 0       59.0    School B         3.85               3.72        93.0
# 1       75.0    School B         3.81               4.00        98.0
# 2       61.0    School C         1.55               1.78        36.0
# 3       65.0    School C         1.36               1.46        35.0
# 4       60.0    School A         3.58               3.24        81.0
#
#    CS Score  English Score  Admission Score Grade
# 0      75.0           93.0             85.0     B
# 1      78.0           99.0             81.0     B
# 2      47.0           36.0             38.0     D
# 3      64.0           35.0             41.0     D
# 4      92.0           81.0             69.0     B

# %%
cleaner = DataCleaner('students.csv',missing='drop',duplicates=False,show_log=True)
df = cleaner.clean()
print(df.head())
# Out:
# [DataCleaner INFO]: Loading Data from students.csv
# [DataCleaner INFO]: Data loaded sucessfully with shape (5001, 19)
# [DataCleaner INFO]: Duplicates removal skipped
# [DataCleaner INFO]: Handling missing values using: drop
#
# Correlation Matrix
#
#                         Student ID  Admission Year  Graduate Year  \
# Student ID                    1.00            0.01           0.01
# Admission Year                0.01            1.00           0.90
# Graduate Year                 0.01            0.90           1.00
# Expected Graduate Year        0.00            0.90           0.81
# Secondary School GPA         -0.01            0.01           0.01
# GAT Scores                    0.03            0.01           0.02
# AAT Score                     0.00            0.01           0.00
# Student GPA                   0.00            0.01           0.00
# Last Semester GPA             0.00           -0.00          -0.00
# Math Score                   -0.01           -0.01          -0.02
# CS Score                     -0.02           -0.01          -0.01
# English Score                -0.01           -0.01          -0.02
# Admission Score              -0.01            0.00          -0.00
#
#                         Expected Graduate Year  Secondary School GPA  \
# Student ID                                0.00                 -0.01
# Admission Year                            0.90                  0.01
# Graduate Year                             0.81                  0.01
# Expected Graduate Year                    1.00                  0.00
# Secondary School GPA                      0.00                  1.00
# GAT Scores                                0.01                 -0.01
# AAT Score                                 0.01                 -0.02
# Student GPA                               0.01                 -0.02
# Last Semester GPA                         0.00                 -0.01
# Math Score                               -0.00                 -0.03
# CS Score                                  0.01                 -0.02
# English Score                            -0.00                 -0.03
# Admission Score                           0.00                 -0.03
#
#                         GAT Scores  AAT Score  Student GPA  Last Semester GPA  \
# Student ID                    0.03       0.00         0.00               0.00
# Admission Year                0.01       0.01         0.01              -0.00
# Graduate Year                 0.02       0.00         0.00              -0.00
# Expected Graduate Year        0.01       0.01         0.01               0.00
# Secondary School GPA         -0.01      -0.02        -0.02              -0.01
# GAT Scores                    1.00       0.00        -0.00               0.01
# AAT Score                     0.00       1.00        -0.02              -0.01
# Student GPA                  -0.00      -0.02         1.00               0.95
# Last Semester GPA             0.01      -0.01         0.95               1.00
# Math Score                   -0.00      -0.02         0.67               0.62
# CS Score                      0.01      -0.02         0.66               0.62
# English Score                -0.00      -0.02         0.67               0.62
# Admission Score              -0.00      -0.02         0.90               0.85
#
#                         Math Score  CS Score  English Score  Admission Score
# Student ID                   -0.01     -0.02          -0.01            -0.01
# Admission Year               -0.01     -0.01          -0.01             0.00
# Graduate Year                -0.02     -0.01          -0.02            -0.00
# Expected Graduate Year       -0.00      0.01          -0.00             0.00
# Secondary School GPA         -0.03     -0.02          -0.03            -0.03
# GAT Scores                   -0.00      0.01          -0.00            -0.00
# AAT Score                    -0.02     -0.02          -0.02            -0.02
# Student GPA                   0.67      0.66           0.67             0.90
# Last Semester GPA             0.62      0.62           0.62             0.85
# Math Score                    1.00      0.53           1.00             0.73
# CS Score                      0.53      1.00           0.53             0.73
# English Score                 1.00      0.53           1.00             0.73
# Admission Score               0.73      0.73           0.73             1.00
# [DataCleaner INFO]: Cleaning complete
#    Student ID     Sex   Campus Name Major Student Status  Admission Year  \
# 0    100000.0    Male  North Campus  CNET        regular          2019.0
# 2    100002.0    Male   West Campus    IT        regular          2018.0
# 3    100003.0    Male   Main Campus    CS  discontinuous          2019.0
# 4    100004.0    Male  North Campus  CNET       graduate          2016.0
# 5    100005.0  Female   Main Campus  CNET  discontinuous          2018.0
#
#    Graduate Year  Expected Graduate Year  Secondary School GPA  GAT Scores  \
# 0         2024.0                  2022.0                 62.52        66.0
# 2         2022.0                  2023.0                 80.65        90.0
# 3         2022.0                  2024.0                 99.12        51.0
# 4         2022.0                  2022.0                 83.79        61.0
# 5         2024.0                  2021.0                 97.96        91.0
#
#    AAT Score School Name  Student GPA  Last Semester GPA  Math Score  \
# 0       59.0    School B         3.85               3.72        93.0
# 2       61.0    School C         1.55               1.78        36.0
# 3       65.0    School C         1.36               1.46        35.0
# 4       60.0    School A         3.58               3.24        81.0
# 5       66.0    School B         4.18               3.84        59.0
#
#    CS Score  English Score  Admission Score Grade
# 0      75.0           93.0             85.0     B
# 2      47.0           36.0             38.0     D
# 3      64.0           35.0             41.0     D
# 4      92.0           81.0             69.0     B
# 5      52.0           59.0             82.0     A
